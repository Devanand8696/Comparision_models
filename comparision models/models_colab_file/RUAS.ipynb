# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir("/content/drive/MyDrive/RUAS-main/RUAS-main/")

# %%
# !python  test.py  --data_path  "/content/drive/MyDrive/LOLdataset_main/eval15/low"  --model "lol"
# Out:
# gpu device = 0
# args = %s Namespace(data_path='/content/drive/MyDrive/LOLdataset_main/eval15/low', save_path='./RUAS_LOL', model='lol', gpu=0, seed=2)
# /content/drive/MyDrive/RUAS-main/RUAS-main/test.py:67: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input = Variable(input, volatile=True).cuda()
# processing /content/drive/MyDrive/LOLdataset_main/eval15/low/1_0.png
# processing /content/drive/MyDrive/LOLdataset_main/eval15/low/1_0.png
# processing /content/drive/MyDrive/LOLdataset_main/eval15/low/111_0.png
# processing /content/drive/MyDrive/LOLdataset_main/eval15/low/111_0.png
# processing /content/drive/MyDrive/LOLdataset_main/eval15/low/111_0_0.png
# processing /content/drive/MyDrive/LOLdataset_main/eval15/low/111_0_0.png
# processing /content/drive/MyDrive/LOLdataset_main/eval15/low/111_0_0_0.png
# processing /content/drive/MyDrive/LOLdataset_main/eval15/low/111_0_0_0.png
# ...
