# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir("/content/drive/MyDrive/DLN-master/DLN-master")

# %%
# !python test.py
# Out:
# Namespace(upscale_factor=1, testBatchSize=32, gpu_mode=True, chop_forward=True, patch_size=256, stride=16, threads=1, seed=123, gpus=1, image_dataset='/content/drive/MyDrive/LOLdataset_main/eval15/low', model_type='DLN', output='/content/drive/MyDrive/LOL_RESULTS_NEW_MODELS/DLN_LOL', modelfile='/content/drive/MyDrive/DLN-master/DLN-master/models/DLN_pretrained.pth', image_based=True, chop=False)
# ===> Building model  DLN
# /content/drive/MyDrive/LOLdataset_main/eval15/low
# ...
