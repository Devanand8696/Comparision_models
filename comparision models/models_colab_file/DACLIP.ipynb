# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir("/content/drive/MyDrive/daclip-uir-main/universal-image-restoration/config/daclip-sde")

# %%
# !pip install lpips
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.0 MB/s eta 0:00:00
# ...

# %%
# !pip install ftfy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip install lmdb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# !pip install ema_pytorch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.1/819.1 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# !pip install einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 879.3 kB/s eta 0:00:00
# ...

# %%
# !python test.py -opt=options/test.yml
# Out:
# export CUDA_VISIBLE_DEVICES=0
# OrderedDict([('name', 'Test'), ('mode', 'LQGT'), ('dataroot_GT', '/content/drive/MyDrive/model_datasets/lime_subpart'), ('dataroot_LQ', '/content/drive/MyDrive/model_datasets/lime_subpart')])
# 24-01-16 13:32:19.895 - INFO:   name: universal-ir
#   suffix: None
#   model: denoising
#   distortion: ['motion-blurry', 'hazy', 'jpeg-compressed', 'low-light', 'noisy', 'raindrop', 'rainy', 'shadowed', 'snowy', 'uncompleted']
#   gpu_ids: [0]
#   sde:[
#     max_sigma: 50
#     T: 100
#     schedule: cosine
#     eps: 0.005
#   ]
#   degradation:[
#     sigma: 25
#     noise_type: G
#     scale: 4
#   ]
#   datasets:[
#     test1:[
#       name: Test
#       mode: LQGT
#       dataroot_GT: /content/drive/MyDrive/model_datasets/lime_subpart
#       dataroot_LQ: /content/drive/MyDrive/model_datasets/lime_subpart
#       phase: test1
#       scale: 1
# ...
